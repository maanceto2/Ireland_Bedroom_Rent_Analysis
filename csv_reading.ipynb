# %%
import pandas as pd

check = pd.read_csv("./Raw_data/multiple_csv/Dublin_Rent/Double/rent_data_double_dublin27.csv")

check.loc[:]
# Out:
#             prices                                          available  \
# 0      €190 weekly  Available Now - Ucd/trinity - college rental\n...
# 1     €900 monthly  Available Now - Beautiful home in the center o...
# 2     €400 monthly  Available Now - -- weekends only --  room not ...
# 3     €900 monthly  Available 28th August - We have a spacious dou...
# 4   €1,000 monthly  Available 8th September - Recently renovated h...
# 5   €1,100 monthly  Available Now - Modern and stylish double room...
# 6   €1,050 monthly  Available Now - Double room in newly decorated...
# 7   €1,000 monthly  Available Now - Large double bedroom ready to ...
# 8   €1,000 monthly  Available Now - Available from august1st. Love...
# 9   €1,400 monthly  Available 15th September - Discover a better s...
# 10  €1,200 monthly  Available Now - *long term accommodation avail...
# 11    €800 monthly  Available 1st September - Modern 2 bedroom apa...
# ...
